# %% [markdown]
# # Projeto Análise de Microdados do ENEM

# %%
import pandas as pd
import matplotlib as mt

# %%
microdados = pd.read_csv('D:\DADOS\enem-2020-microdados\DADOS\MICRODADOS_ENEM_2020.csv', sep=";", encoding="ISO-8859-1")

# %%
microdados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  200006271946    2020               11       F                1
# 1  200001195856    2020               11       M                2
# 2  200001943954    2020                4       F                2
# 3  200001908998    2020                2       M                1
# 4  200001634757    2020                4       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1               11          1
# 1            3                 1                1               11          1
# 2            3                 2                2                0          2
# 3            3                 1                2                0          2
# 4            3                 2                1                1          1
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
microdados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783109 entries, 0 to 5783108
# Data columns (total 76 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_INSCRICAO            int64
#  1   NU_ANO                  int64
#  2   TP_FAIXA_ETARIA         int64
#  3   TP_SEXO                 object
#  4   TP_ESTADO_CIVIL         int64
#  5   TP_COR_RACA             int64
#  6   TP_NACIONALIDADE        int64
#  7   TP_ST_CONCLUSAO         int64
#  8   TP_ANO_CONCLUIU         int64
#  9   TP_ESCOLA               int64
#  10  TP_ENSINO               float64
#  11  IN_TREINEIRO            int64
#  12  CO_MUNICIPIO_ESC        float64
#  13  NO_MUNICIPIO_ESC        object
#  14  CO_UF_ESC               float64
#  15  SG_UF_ESC               object
#  16  TP_DEPENDENCIA_ADM_ESC  float64
#  17  TP_LOCALIZACAO_ESC      float64
#  18  TP_SIT_FUNC_ESC         float64
#  19  CO_MUNICIPIO_PROVA      int64
#  20  NO_MUNICIPIO_PROVA      object
# ...

# %%
microdados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
column_selected = ['TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
       'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
       'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
       'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
       'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
       'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
       'Q023', 'Q024', 'Q025']

# %%
microdados_selected = microdados.filter(items=column_selected)

# %%
microdados_selected.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  \
# 0               11       F                1            2                 1
# 1               11       M                2            3                 1
# 2                4       F                2            3                 2
# 3                2       M                1            3                 1
# 4                4       F                1            3                 2
#
#    TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  TP_ENSINO  IN_TREINEIRO  ...  \
# 0                1               11          1        NaN             0  ...
# 1                1               11          1        NaN             0  ...
# 2                2                0          2        1.0             0  ...
# 3                2                0          2        1.0             0  ...
# 4                1                1          1        NaN             0  ...
#
# ...

# %%
municipios = microdados_selected['NO_MUNICIPIO_ESC']

# %%
municipios
# Out:
# 0                          NaN
# 1                          NaN
# 2                     Salvador
# 3          Santana de Parnaíba
# 4                          NaN
#                   ...
# 5783104                Crateús
# 5783105            Três Lagoas
# 5783106                    NaN
# 5783107                 Cuiabá
# 5783108               São Luís
# Name: NO_MUNICIPIO_ESC, Length: 5783109, dtype: object

# %%
municipios.value_counts().sort_index()
# Out:
# Abadia de Goiás         23
# Abadia dos Dourados     13
# Abadiânia               99
# Abaetetuba             850
# Abaeté                  66
#                       ...
# Áurea                    9
# Ângulo                   3
# Érico Cardoso           26
# Óbidos                  81
# Óleo                    17
# Name: NO_MUNICIPIO_ESC, Length: 5268, dtype: int64

# %%
idade = microdados["TP_FAIXA_ETARIA"]

# %%
idade
# Out:
# 0          11
# 1          11
# 2           4
# 3           2
# 4           4
#            ..
# 5783104     2
# 5783105     3
# 5783106     3
# 5783107     4
# 5783108     2
# Name: TP_FAIXA_ETARIA, Length: 5783109, dtype: int64

# %%
idade.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
estado = microdados['SG_UF_ESC']

# %%
estado.value_counts().sort_values()
# Out:
# RR      2453
# AC      3512
# AP      3565
# TO      8457
# RO      9927
# SE     10878
# MS     11851
# AL     13976
# RN     14327
# MT     14674
# PI     15738
# ES     18419
# PB     19760
# DF     19840
# MA     26104
# SC     27373
# AM     30120
# PA     33109
# RS     36478
# GO     39769
# PR     43060
# BA     47235
# PE     47583
# RJ     62583
# MG     71614
# CE    104981
# SP    167183
# Name: SG_UF_ESC, dtype: int64

# %%
estado.hist(bins=27)
# Out:
# <AxesSubplot:>

# %%
sexo = microdados["TP_SEXO"]

# %%
dist_sex = sexo.value_counts().sort_index()

# %%
dist_sex
# Out:
# F    3468805
# M    2314304
# Name: TP_SEXO, dtype: int64

# %%
percentSex = [100 * x / dist_sex.sum() for x in dist_sex]

# %%
percentSex
# Out:
# [59.98166384206142, 40.01833615793858]

# %%
selecao_colunas = ["TP_SEXO", "NU_NOTA_REDACAO"]

# %%
red_sex = microdados.filter(items=selecao_colunas)

# %%
red_sex
# Out:
#         TP_SEXO  NU_NOTA_REDACAO
# 0             F              NaN
# 1             M            580.0
# 2             F              NaN
# 3             M            760.0
# 4             F              NaN
# ...         ...              ...
# 5783104       F            900.0
# 5783105       M            660.0
# 5783106       F            660.0
# 5783107       F              NaN
# 5783108       F            380.0
#
# [5783109 rows x 2 columns]

# %%
red_sex = red_sex.dropna()

# %%
red_sex
# Out:
#         TP_SEXO  NU_NOTA_REDACAO
# 1             M            580.0
# 3             M            760.0
# 5             F            700.0
# 7             M            600.0
# 8             F            600.0
# ...         ...              ...
# 5783103       M            660.0
# 5783104       F            900.0
# 5783105       M            660.0
# 5783106       F            660.0
# 5783108       F            380.0
#
# [2754140 rows x 2 columns]

# %%
red_sex.groupby('TP_SEXO').count()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                1663652
# M                1090488

# %%
red_sex.groupby('TP_SEXO').max()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 1000.0
# M                 1000.0

# %%
red_sex.groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                    0.0
# M                    0.0

# %%
red_sex[red_sex.NU_NOTA_REDACAO > 0].groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                   40.0
# M                   40.0

# %%
red_sex.groupby('TP_SEXO').median()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                  580.0
# M                  560.0

# %%
red_sex.groupby('TP_SEXO').hist()
# Out:
# TP_SEXO
# F    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# M    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object

# %%
red_sex.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                    \
#                   count        mean         std  min    25%    50%    75%
# TP_SEXO
# F             1663652.0  588.297913  196.467114  0.0  480.0  580.0  720.0
# M             1090488.0  550.703832  202.735245  0.0  420.0  560.0  680.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0

# %% [markdown]
# # Parte dois

# %%
columns_select = ["NU_INSCRICAO", 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002']

# %%
microdados_select = microdados.filter(items=columns_select)

# %%
microdados_select = microdados_select.dropna()

# %%
microdados_select
# Out:
#          NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 5        200003132410       526.7            700.0    C    B
# 8        200006762554       448.5            600.0    B    C
# 11       200006138472       546.5            640.0    B    C
# 18       200003343448       420.3            800.0    C    C
# 19       200005966328       405.6            500.0    C    D
# ...               ...         ...              ...  ...  ...
# 5783084  200006585396       411.4            340.0    B    D
# 5783095  200002970643       332.7            440.0    A    B
# 5783101  200002621781       340.0            500.0    D    D
# 5783104  200003396891       725.7            900.0    E    G
# 5783108  200007078230       481.7            380.0    F    D
#
# [2561304 rows x 5 columns]

# %% [markdown]
# # Aplicando Questionário Socioeconômico

# %% [markdown]
# Utilizando as perguntas para fazer um dicionário das alternativas.
#
# Q001 - Até que série seu pai, ou o homem responsável por você, estudou?
#
# Q002 - Até que série sua mãe, ou a mulher responsável por você, estudou?

# %%
Dicio_Quest = {"A": "Nunca estudou.",
               "B": "Não completou a 4ª série/5º ano do Ensino Fundamental.",
               "C": "Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.",
               "D": "Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.",
               "E": "Completou o Ensino Médio, mas não completou a Faculdade.",
               "F": "Completou a Faculdade, mas não completou a Pós-graduação.",
               "G": "Completou a Pós-graduação.",
               "H": "Não sei."
              }

# %% [markdown]
# Criando novas colunas no DataFrame

# %%
microdados_select.filter(items=["Q001", "NU_INSCRICAO"]).groupby("Q001").count()
# Out:
#       NU_INSCRICAO
# Q001
# A           113786
# B           483323
# C           352976
# D           284175
# E           736397
# F           233881
# G           157039
# H           199727

# %%
microdados_select["NO_Q001"] = [Dicio_Quest[x] for x in microdados_select.Q001]

# %%
microdados_select.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 5   200003132410       526.7            700.0    C    B
# 8   200006762554       448.5            600.0    B    C
# 11  200006138472       546.5            640.0    B    C
# 18  200003343448       420.3            800.0    C    C
# 19  200005966328       405.6            500.0    C    D
#
#                                               NO_Q001
# 5   Completou a 4ª série/5º ano, mas não completou...
# 8   Não completou a 4ª série/5º ano do Ensino Fund...
# 11  Não completou a 4ª série/5º ano do Ensino Fund...
# 18  Completou a 4ª série/5º ano, mas não completou...
# 19  Completou a 4ª série/5º ano, mas não completou...

# %%
microdados_select["NO_Q002"] = [Dicio_Quest[x] for x in microdados_select.Q002]

# %%
microdados_select.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 5   200003132410       526.7            700.0    C    B
# 8   200006762554       448.5            600.0    B    C
# 11  200006138472       546.5            640.0    B    C
# 18  200003343448       420.3            800.0    C    C
# 19  200005966328       405.6            500.0    C    D
#
#                                               NO_Q001  \
# 5   Completou a 4ª série/5º ano, mas não completou...
# 8   Não completou a 4ª série/5º ano do Ensino Fund...
# 11  Não completou a 4ª série/5º ano do Ensino Fund...
# 18  Completou a 4ª série/5º ano, mas não completou...
# 19  Completou a 4ª série/5º ano, mas não completou...
#
#                                               NO_Q002
# 5   Não completou a 4ª série/5º ano do Ensino Fund...
# 8   Completou a 4ª série/5º ano, mas não completou...
# 11  Completou a 4ª série/5º ano, mas não completou...
# 18  Completou a 4ª série/5º ano, mas não completou...
# ...

# %% [markdown]
# # Comparando a Distribuição do Nível de Escolaridade Pai x Mãe no Conjunto de Dados

# %% [markdown]
# Utilizando métodos do DataFrame filter(), groupby(), count(), sort_values()

# %% [markdown]
# # Primeiro: Escolaridade do Pai

# %%
microdados_select.filter(items=["NU_INSCRICAO", "NO_Q001"]).groupby("NO_Q001").count().sort_values(by="NU_INSCRICAO", ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q001
# Completou o Ensino Médio, mas não completou a F...        736397
# Não completou a 4ª série/5º ano do Ensino Funda...        483323
# Completou a 4ª série/5º ano, mas não completou ...        352976
# Completou a 8ª série/9º ano do Ensino Fundament...        284175
# Completou a Faculdade, mas não completou a Pós-...        233881
# Não sei.                                                  199727
# Completou a Pós-graduação.                                157039
# Nunca estudou.                                            113786

# %% [markdown]
# # Segundo: Escolaridade da Mãe

# %%
microdados_select.filter(items=["NU_INSCRICAO", "NO_Q002"]).groupby("NO_Q002").count().sort_values(by="NU_INSCRICAO", ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q002
# Completou o Ensino Médio, mas não completou a F...        881498
# Não completou a 4ª série/5º ano do Ensino Funda...        358276
# Completou a Faculdade, mas não completou a Pós-...        312436
# Completou a 4ª série/5º ano, mas não completou ...        306430
# Completou a 8ª série/9º ano do Ensino Fundament...        294949
# Completou a Pós-graduação.                                275108
# Nunca estudou.                                             76337
# Não sei.                                                   56270

# %% [markdown]
# # Verficando o Desempenho em Matemática Segunda a Escolaridade do Pai x Mãe

# %% [markdown]
# # 1 - Escolaridade do Pai

# %%
microdados_select.filter(items=["NO_Q001", "NU_NOTA_MT"]).groupby("NO_Q001").describe()
# Out:
#                                                    NU_NOTA_MT              \
#                                                         count        mean
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...    64551.0  504.016646
# Completou a 8ª série/9º ano do Ensino Fundament...    62249.0  518.301007
# Completou a Faculdade, mas não completou a Pós-...    67702.0  608.550770
# Completou a Pós-graduação.                            50182.0  634.516161
# Completou o Ensino Médio, mas não completou a F...   172097.0  546.393353
# Nunca estudou.                                        12588.0  457.483786
# Não completou a 4ª série/5º ano do Ensino Funda...    63896.0  480.295114
# Não sei.                                              39333.0  499.977406
#
#                                                                             \
#                                                            std  min    25%
# NO_Q001
# ...

# %%
microdados_select.filter(items=["NU_NOTA_MT", "NO_Q001"]).groupby("NO_Q001").mean().sort_values(by="NU_NOTA_MT", ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q001
# Completou a Pós-graduação.                          634.516161
# Completou a Faculdade, mas não completou a Pós-...  608.550770
# Completou o Ensino Médio, mas não completou a F...  546.393353
# Completou a 8ª série/9º ano do Ensino Fundament...  518.301007
# Completou a 4ª série/5º ano, mas não completou ...  504.016646
# Não sei.                                            499.977406
# Não completou a 4ª série/5º ano do Ensino Funda...  480.295114
# Nunca estudou.                                      457.483786

# %% [markdown]
# # 2 - Escolaridade da Mãe

# %%
microdados_select.filter(items=["NO_Q002", "NU_NOTA_MT"]).groupby("NO_Q002").describe()
# Out:
#                                                    NU_NOTA_MT              \
#                                                         count        mean
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...   306430.0  488.812625
# Completou a 8ª série/9º ano do Ensino Fundament...   294949.0  499.628369
# Completou a Faculdade, mas não completou a Pós-...   312436.0  580.438367
# Completou a Pós-graduação.                           275108.0  594.897645
# Completou o Ensino Médio, mas não completou a F...   881498.0  523.880757
# Nunca estudou.                                        76337.0  448.565889
# Não completou a 4ª série/5º ano do Ensino Funda...   358276.0  470.848168
# Não sei.                                              56270.0  478.135403
#
#                                                                             \
#                                                            std  min    25%
# NO_Q002
# ...

# %%
microdados_select.filter(items=["NU_NOTA_MT", "NO_Q002"]).groupby("NO_Q002").mean().sort_values(by="NU_NOTA_MT", ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q002
# Completou a Pós-graduação.                          610.153089
# Completou a Faculdade, mas não completou a Pós-...  594.487400
# Completou o Ensino Médio, mas não completou a F...  535.107086
# Completou a 8ª série/9º ano do Ensino Fundament...  504.549913
# Completou a 4ª série/5º ano, mas não completou ...  491.164163
# Não sei.                                            486.941939
# Não completou a 4ª série/5º ano do Ensino Funda...  470.241244
# Nunca estudou.                                      448.587719

# %% [markdown]
# # Verificando Desempenho em Redação de acordo com a Escolaridade do Pai e da Mãe.

# %% [markdown]
# # 1 - Pai

# %%
microdados_select.filter(items=["NU_NOTA_REDACAO", "NO_Q001"]).groupby("NO_Q001").mean().sort_values(by="NU_NOTA_REDACAO", ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q001
# Completou a Pós-graduação.                               729.397792
# Completou a Faculdade, mas não completou a Pós-...       695.076364
# Completou o Ensino Médio, mas não completou a F...       624.059571
# Completou a 8ª série/9º ano do Ensino Fundament...       586.804286
# Completou a 4ª série/5º ano, mas não completou ...       567.705225
# Não sei.                                                 552.275189
# Não completou a 4ª série/5º ano do Ensino Funda...       533.301615
# Nunca estudou.                                           494.129330

# %%
microdados_select.filter(items=["NU_NOTA_REDACAO", "NO_Q001"]).groupby("NO_Q001").describe()
# Out:
#                                                    NU_NOTA_REDACAO  \
#                                                              count
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...        352976.0
# Completou a 8ª série/9º ano do Ensino Fundament...        284175.0
# Completou a Faculdade, mas não completou a Pós-...        233881.0
# Completou a Pós-graduação.                                157039.0
# Completou o Ensino Médio, mas não completou a F...        736397.0
# Nunca estudou.                                            113786.0
# Não completou a 4ª série/5º ano do Ensino Funda...        483323.0
# Não sei.                                                  199727.0
#
#                                                                             \
#                                                           mean         std
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...  555.248572  187.980927
# ...

# %% [markdown]
# # 2 - Mãe

# %%
microdados_select.filter(items=["NU_NOTA_REDACAO", "NO_Q002"]).groupby("NO_Q002").mean().sort_values(by="NU_NOTA_REDACAO", ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação.                               703.645277
# Completou a Faculdade, mas não completou a Pós-...       679.745940
# Completou o Ensino Médio, mas não completou a F...       609.437322
# Completou a 8ª série/9º ano do Ensino Fundament...       567.123746
# Completou a 4ª série/5º ano, mas não completou ...       547.964557
# Não completou a 4ª série/5º ano do Ensino Funda...       515.430502
# Não sei.                                                 514.565493
# Nunca estudou.                                           474.972790

# %%
microdados_select.filter(items=["NU_NOTA_REDACAO", "NO_Q002"]).groupby("NO_Q002").describe()
# Out:
#                                                    NU_NOTA_REDACAO  \
#                                                              count
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...        306430.0
# Completou a 8ª série/9º ano do Ensino Fundament...        294949.0
# Completou a Faculdade, mas não completou a Pós-...        312436.0
# Completou a Pós-graduação.                                275108.0
# Completou o Ensino Médio, mas não completou a F...        881498.0
# Nunca estudou.                                             76337.0
# Não completou a 4ª série/5º ano do Ensino Funda...        358276.0
# Não sei.                                                   56270.0
#
#                                                                             \
#                                                           mean         std
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...  538.449630  184.928330
# ...

# %% [markdown]
# # Verificando Média em Redação Pela Escolaridade de Pai X Mãe Com Foco na UF

# %%
columns_select = ["NU_INSCRICAO", 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002', "SG_UF_ESC"]

# %%
microdados_select = microdados.filter(items=columns_select)

# %%
microdados_select = microdados_select.dropna()

# %%
microdados_select.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002 SG_UF_ESC
# 36  200003209996       433.9            620.0    E    E        AM
# 65  200003350911       384.2            880.0    A    C        PI
# 84  200005725669       404.6            600.0    C    E        MT
# 89  200004462096       669.8            820.0    B    C        SP
# 93  200002727241       743.0            920.0    E    E        RJ

# %% [markdown]
# # 1 - Mãe

# %%
microdados_select.filter(items=["NU_NOTA_REDACAO", "NO_Q002"]).where(microdados_select.SG_UF_ESC == "RJ").groupby("NO_Q002").mean().sort_values(by="NU_NOTA_REDACAO", ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação.                               752.325883
# Completou a Faculdade, mas não completou a Pós-...       717.670617
# Completou o Ensino Médio, mas não completou a F...       625.613800
# Completou a 8ª série/9º ano do Ensino Fundament...       583.209483
# Completou a 4ª série/5º ano, mas não completou ...       576.738255
# Não sei.                                                 563.134978
# Não completou a 4ª série/5º ano do Ensino Funda...       554.585815
# Nunca estudou.                                           514.285714

# %% [markdown]
# Verificando Por SP

# %%
microdados_select.filter(items=["NU_NOTA_REDACAO", "NO_Q002"]).where(microdados_select.SG_UF_ESC == "SP").groupby("NO_Q002").mean().sort_values(by="NU_NOTA_REDACAO", ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação.                               682.406866
# Completou a Faculdade, mas não completou a Pós-...       664.238143
# Completou o Ensino Médio, mas não completou a F...       605.642481
# Completou a 8ª série/9º ano do Ensino Fundament...       576.942993
# Completou a 4ª série/5º ano, mas não completou ...       570.986239
# Não completou a 4ª série/5º ano do Ensino Funda...       546.751781
# Não sei.                                                 542.446483
# Nunca estudou.                                           493.243243

# %% [markdown]
# # Verificando de Todos os Estados

# %%
microdados_select.filter(items=["NU_NOTA_REDACAO", "NO_Q002", "SG_UF_ESC"]).groupby(["SG_UF_ESC", "NO_Q002"]).mean()
# Out:
#                                                               NU_NOTA_REDACAO
# SG_UF_ESC NO_Q002
# AC        Completou a 4ª série/5º ano, mas não completou ...       521.871921
#           Completou a 8ª série/9º ano do Ensino Fundament...       542.767857
#           Completou a Faculdade, mas não completou a Pós-...       624.189526
#           Completou a Pós-graduação.                               654.095745
#           Completou o Ensino Médio, mas não completou a F...       556.282723
# ...                                                                       ...
# TO        Completou a Pós-graduação.                               655.590327
#           Completou o Ensino Médio, mas não completou a F...       561.460751
#           Nunca estudou.                                           377.254902
#           Não completou a 4ª série/5º ano do Ensino Funda...       464.587814
#           Não sei.                                                 516.382979
#
# ...

# %% [markdown]
# # Utilizando Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
#fig, ax = plt.subplots(figsize=(20,10))
#plt.suptitle("Nota Redacao X Escolaridade X Estado")


ax = microdados_select.filter(items=["SG_UF_ESC","Q002","NU_NOTA_REDACAO"])\
.groupby(["Q002", "SG_UF_ESC"])\
.mean().sort_values(by="NU_NOTA_REDACAO", ascending=False)\
.unstack().plot(figsize=(22,12), colormap="viridis")

ax.set_title("Nota Redacao X Escolaridade X Estado", fontsize=20)
#ax.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)

handles, labels = ax.get_legend_handles_labels()

import re

edited_labels = [re.search(',\s(.+?)\)', label).group(1) for label in labels]
ax.legend(edited_labels, bbox_to_anchor=(1.07, 1), loc=0, borderaxespad=0., fontsize=12)


textDictQ002 = ""
for key, value in Dicio_Quest.items():
    textDictQ002 = textDictQ002 + "{key} : {value}\n".format(key=key, value=value)

ax.text(0.02, 0.75, textDictQ002, transform=ax.transAxes, fontsize=14, color = "black",
        bbox={"boxstyle":"round", "facecolor":"darkturquoise", "alpha":0.8})
# Out:
# Text(0.02, 0.75, 'A : Nunca estudou.\nB : Não completou a 4ª série/5º ano do Ensino Fundamental.\nC : Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.\nD : Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.\nE : Completou o Ensino Médio, mas não completou a Faculdade.\nF : Completou a Faculdade, mas não completou a Pós-graduação.\nG : Completou a Pós-graduação.\nH : Não sei.\n')

# %% [markdown]
# # Exportando Dados para CSV

# %%
microdados_enem_reduzido = microdados.filter(items=["CO_MUNICIPIO_PROVA", "NO_MUNICIPIO_PROVA", "SG_UF_ESC", "CO_UF_ESC", 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', "NU_NOTA_REDACAO"])

# %%
microdados_enem_reduzido.head()
# Out:
#    CO_MUNICIPIO_PROVA   NO_MUNICIPIO_PROVA SG_UF_ESC  CO_UF_ESC  NU_NOTA_CN  \
# 0             1501402                Belém       NaN        NaN         NaN
# 1             2408102                Natal       NaN        NaN       604.1
# 2             2927408             Salvador        BA       29.0         NaN
# 3             3547304  Santana de Parnaíba        SP       35.0       620.8
# 4             3121605           Diamantina       NaN        NaN         NaN
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0         NaN         NaN         NaN              NaN
# 1       661.7       595.3       711.3            580.0
# 2         NaN         NaN         NaN              NaN
# 3       675.0       624.2       759.4            760.0
# 4         NaN         NaN         NaN              NaN

# %%
mediaEnemporMunicipio = microdados_enem_reduzido.groupby(["CO_MUNICIPIO_PROVA", "NO_MUNICIPIO_PROVA","CO_UF_ESC","SG_UF_ESC"], as_index=False).mean()

# %%
mediaEnemporMunicipio
# Out:
#       CO_MUNICIPIO_PROVA     NO_MUNICIPIO_PROVA  CO_UF_ESC SG_UF_ESC  \
# 0                1100015  Alta Floresta D'Oeste       11.0        RO
# 1                1100023              Ariquemes       11.0        RO
# 2                1100023              Ariquemes       21.0        MA
# 3                1100023              Ariquemes       33.0        RJ
# 4                1100023              Ariquemes       35.0        SP
# ...                  ...                    ...        ...       ...
# 3498             5300108               Brasília       42.0        SC
# 3499             5300108               Brasília       43.0        RS
# 3500             5300108               Brasília       50.0        MS
# 3501             5300108               Brasília       52.0        GO
# 3502             5300108               Brasília       53.0        DF
#
#       NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# ...

# %%
mediaEnemporMunicipio.to_csv("mediaEnemporMunicipio.csv")

# %% [markdown]
# # Nota no Enem x IDHM

# %%
mediaPorMunicipio = pd.read_csv("mediaEnemporMunicipio.csv", sep=",", index_col=0)

# %%
mediaPorMunicipio.head()
# Out:
#    CO_MUNICIPIO_PROVA     NO_MUNICIPIO_PROVA  CO_UF_ESC SG_UF_ESC  NU_NOTA_CN  \
# 0             1100015  Alta Floresta D'Oeste       11.0        RO  492.916901
# 1             1100023              Ariquemes       11.0        RO  489.352416
# 2             1100023              Ariquemes       21.0        MA         NaN
# 3             1100023              Ariquemes       33.0        RJ  599.000000
# 4             1100023              Ariquemes       35.0        SP         NaN
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0  504.947297  517.564865  512.009859       603.243243
# 1  500.852721  515.446259  512.185502       549.591837
# 2         NaN         NaN         NaN              NaN
# 3  669.500000  568.600000  736.300000       780.000000
# 4         NaN         NaN         NaN              NaN
